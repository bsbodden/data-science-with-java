// %% [markdown]
// # Testing the JJava Kernel
//
// ![java](../media/java.png "Java Rules!")

// %%
// Import our core glue code
import static org.jjavaglue.core.J.*;

println("Hellllloooo Worlddddd!");
// Out:
// Hellllloooo Worlddddd!

// %%
import static org.jjavaglue.dflib.ImageUtil.*;

showImage("../media/jc.png");
